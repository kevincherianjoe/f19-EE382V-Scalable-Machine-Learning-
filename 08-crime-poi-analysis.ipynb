# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(2, 3, figsize=(10, 10))

cat = 'pawn_shop'
poi_data = list(csv.reader(open('./data/poi_index_' + cat + '.csv')))
a = np.array(poi_data, dtype=str).astype(np.float)
axs[0,0].imshow(a, cmap='hot', interpolation='nearest')
axs[0,0].set_title(cat)

cat = 'schools'
poi_data = list(csv.reader(open('./data/poi_index_' + cat + '.csv')))
a = np.array(poi_data, dtype=str).astype(np.float)
axs[0,1].imshow(a, cmap='hot', interpolation='nearest')
axs[0,1].set_title(cat)

cat = 'park'
poi_data = list(csv.reader(open('./data/poi_index_' + cat + '.csv')))
a = np.array(poi_data, dtype=str).astype(np.float)
axs[0,2].imshow(a, cmap='hot', interpolation='nearest')
axs[0,2].set_title(cat)

cat = 'taco_bell'
poi_data = list(csv.reader(open('./data/poi_index_' + cat + '.csv')))
a = np.array(poi_data, dtype=str).astype(np.float)
axs[1,0].imshow(a, cmap='hot', interpolation='nearest')
axs[1,0].set_title(cat)

cat = 'event'
poi_data = list(csv.reader(open('./data/poi_index_' + cat + '.csv')))
a = np.array(poi_data, dtype=str).astype(np.float)
axs[1,1].imshow(a, cmap='hot', interpolation='nearest')
axs[1,1].set_title(cat)

cat = 'mcdonalds'
poi_data = list(csv.reader(open('./data/poi_index_' + cat + '.csv')))
a = np.array(poi_data, dtype=str).astype(np.float)
axs[1,2].imshow(a, cmap='hot', interpolation='nearest')
axs[1,2].set_title(cat)
# Out:
# Text(0.5, 1.0, 'mcdonalds')
